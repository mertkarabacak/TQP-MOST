# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
#Read all data.

main_puf = pd.read_csv("/content/drive/MyDrive/NTDB-PUFs/NTDB_2021/PUF_TRAUMA.csv", index_col = 'inc_key', low_memory = False)
preexisting_conditions = pd.read_csv("/content/drive/MyDrive/NTDB-PUFs/NTDB_2021/PUF_PREEXISTINGCONDITIONS_PIVOT.csv", index_col = 'Inc_Key', low_memory = False)
hospital_events = pd.read_csv("/content/drive/MyDrive/NTDB-PUFs/NTDB_2021/PUF_HOSPITALEVENTS_PIVOT.csv", index_col = 'Inc_Key', low_memory = False)
ais = pd.read_csv("/content/drive/MyDrive/NTDB-PUFs/NTDB_2021/PUF_AISDIAGNOSIS_PIVOT.csv", index_col = 'inc_key', low_memory = False)
ecode = pd.read_csv("/content/drive/MyDrive/NTDB-PUFs/NTDB_2021/PUF_ECODE.csv", index_col = 'inc_key', low_memory = False)
interventions = pd.read_csv("/content/drive/MyDrive/NTDB-PUFs/NTDB_2021/PUF_INTERVENTIONS.csv", index_col = 'Inc_Key', low_memory = False)

# %%
data = pd.concat([main_puf, preexisting_conditions, hospital_events, ais, ecode, interventions], axis=1)
data.columns = map(str.upper, data.columns)
data.shape
# Out:
# (1209097, 301)

# %% [markdown]
# #Inclusion and Exclusion Criteria

# %%
#Identify the patient population.

data = data[(data['TOTALGCS'] <= 14)]

included = data.shape[0]

print('Number of patients included: ', included)
# Out:
# Number of patients included:  210196

# %%
#Exclude pediatric patients.

before = data.shape[0]
data = data[(data['AGEYEARS'] >= 16)]
after = data.shape[0]
excluded = before - after

print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  210196
# Number of patients after exclusion:  183023
# Number of patients excluded with this criteria:  27173

# %%
#Exclude AIS injury severity score ≥ 3 to neck.

before = data.shape[0]
data = data[data['AISSEVERITY3'] < 3]
after = data.shape[0]
excluded = before - after

print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  183023
# Number of patients after exclusion:  179134
# Number of patients excluded with this criteria:  3889

# %%
#Exclude AIS injury severity score ≥ 3 to thorax.

before = data.shape[0]
data = data[data['AISSEVERITY4'] < 3]
after = data.shape[0]
excluded = before - after

print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  179134
# Number of patients after exclusion:  140172
# Number of patients excluded with this criteria:  38962

# %%
#Exclude AIS injury severity score ≥ 3 to abdomen.

before = data.shape[0]
data = data[data['AISSEVERITY5'] < 3]
after = data.shape[0]
excluded = before - after

print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  140172
# Number of patients after exclusion:  134846
# Number of patients excluded with this criteria:  5326

# %%
#Exclude AIS injury severity score ≥ 3 to spine.

before = data.shape[0]
data = data[data['AISSEVERITY6'] < 3]
after = data.shape[0]
excluded = before - after

print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  134846
# Number of patients after exclusion:  129374
# Number of patients excluded with this criteria:  5472

# %%
#Exclude AIS injury severity score ≥ 3 to upper extremity.

before = data.shape[0]
data = data[data['AISSEVERITY7'] < 3]
after = data.shape[0]
excluded = before - after

print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  129374
# Number of patients after exclusion:  127911
# Number of patients excluded with this criteria:  1463

# %%
#Exclude AIS injury severity score ≥ 3 to lower extremity.

before = data.shape[0]
data = data[data['AISSEVERITY8'] < 3]
after = data.shape[0]
excluded = before - after

print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  127911
# Number of patients after exclusion:  110195
# Number of patients excluded with this criteria:  17716

# %%
#Exclude AIS injury severity score ≥ 3 to unspecified body regions.

before = data.shape[0]
data = data[data['AISSEVERITY9'] < 3]
after = data.shape[0]
excluded = before - after

print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  110195
# Number of patients after exclusion:  110057
# Number of patients excluded with this criteria:  138

# %%
#Exclude patients dead on arrival (SBP=0).

before = data.shape[0]
data = data[data['SBP'] != 0]
after = data.shape[0]
excluded = before - after

print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  110057
# Number of patients after exclusion:  107589
# Number of patients excluded with this criteria:  2468

# %%
#Exclude patients with advanced directive limiting care.

before = data.shape[0]
data = data[data['CC_ADLC'] != 'Yes']
after = data.shape[0]
excluded = before - after

print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  107589
# Number of patients after exclusion:  102138
# Number of patients excluded with this criteria:  5451

# %%
#Drop patients with invalid GCS.

before = data.shape[0]
data = data[data['PMGCSQ_VALID'] == 1]
after = data.shape[0]

excluded = before - after
print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  102138
# Number of patients after exclusion:  39986
# Number of patients excluded with this criteria:  62152

# %%
#Drop patients with unknown GCS.

before = data.shape[0]
data = data[data['TOTALGCS'].notna()]
after = data.shape[0]

excluded = before - after
print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  39986
# Number of patients after exclusion:  39986
# Number of patients excluded with this criteria:  0

# %%
#Drop patients with unknown GCS-Motor.

before = data.shape[0]
data = data[data['GCSMOTOR'].notna()]
after = data.shape[0]

excluded = before - after
print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  39986
# Number of patients after exclusion:  39855
# Number of patients excluded with this criteria:  131

# %%
#Drop patients with unknown GCS-Verbal.

before = data.shape[0]
data = data[data['GCSVERBAL'].notna()]
after = data.shape[0]

excluded = before - after
print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  39855
# Number of patients after exclusion:  39848
# Number of patients excluded with this criteria:  7

# %%
#Drop patients with unknown GCS-Eye.

before = data.shape[0]
data = data[data['GCSEYE'].notna()]
after = data.shape[0]

excluded = before - after
print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  39848
# Number of patients after exclusion:  39845
# Number of patients excluded with this criteria:  3

# %%
#Drop patients with unknown pupillary response.

before = data.shape[0]
data = data[data['TBIPUPILLARYRESPONSE'].notna()]
after = data.shape[0]

excluded = before - after
print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  39845
# Number of patients after exclusion:  38759
# Number of patients excluded with this criteria:  1086

# %%
#Save data.

data.to_csv('/content/drive/MyDrive/GCS-Pupil/stbi_2021_crash.csv')
