# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
#Read all data.

main_puf = pd.read_csv("/content/drive/MyDrive/NTDB-PUFs/NTDB_2021/PUF_TRAUMA.csv", index_col = 'inc_key', low_memory = False)
preexisting_conditions = pd.read_csv("/content/drive/MyDrive/NTDB-PUFs/NTDB_2021/PUF_PREEXISTINGCONDITIONS_PIVOT.csv", index_col = 'Inc_Key', low_memory = False)
hospital_events = pd.read_csv("/content/drive/MyDrive/NTDB-PUFs/NTDB_2021/PUF_HOSPITALEVENTS_PIVOT.csv", index_col = 'Inc_Key', low_memory = False)
ais = pd.read_csv("/content/drive/MyDrive/NTDB-PUFs/NTDB_2021/PUF_AISDIAGNOSIS_PIVOT.csv", index_col = 'inc_key', low_memory = False)
ecode = pd.read_csv("/content/drive/MyDrive/NTDB-PUFs/NTDB_2021/PUF_ECODE.csv", index_col = 'inc_key', low_memory = False)
interventions = pd.read_csv("/content/drive/MyDrive/NTDB-PUFs/NTDB_2021/PUF_INTERVENTIONS.csv", index_col = 'Inc_Key', low_memory = False)

# %%
data = pd.concat([main_puf, preexisting_conditions, hospital_events, ais, ecode, interventions], axis=1)
data.columns = map(str.upper, data.columns)
data.shape
# Out:
# (1209097, 301)

# %% [markdown]
# #Inclusion and Exclusion Criteria

# %%
#Identify the patient population.

data = data[(data['TOTALGCS'] <= 12)]
data = data[(data['VERIFICATIONLEVEL'] == 1) | (data['VERIFICATIONLEVEL'] == 2)]

included = data.shape[0]

print('Number of patients included: ', included)
# Out:
# Number of patients included:  63610

# %%
#Exclude pediatric patients.

before = data.shape[0]
data = data[(data['AGEYEARS'] >= 14)]
after = data.shape[0]
excluded = before - after

print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  63610
# Number of patients after exclusion:  59539
# Number of patients excluded with this criteria:  4071

# %%
#Exclude AIS injury severity score ≥ 3 to neck.

before = data.shape[0]
data = data[data['AISSEVERITY3'] < 3]
after = data.shape[0]
excluded = before - after

print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  59539
# Number of patients after exclusion:  57159
# Number of patients excluded with this criteria:  2380

# %%
#Exclude AIS injury severity score ≥ 3 to thorax.

before = data.shape[0]
data = data[data['AISSEVERITY4'] < 3]
after = data.shape[0]
excluded = before - after

print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  57159
# Number of patients after exclusion:  39829
# Number of patients excluded with this criteria:  17330

# %%
#Exclude AIS injury severity score ≥ 3 to abdomen.

before = data.shape[0]
data = data[data['AISSEVERITY5'] < 3]
after = data.shape[0]
excluded = before - after

print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  39829
# Number of patients after exclusion:  37599
# Number of patients excluded with this criteria:  2230

# %%
#Exclude AIS injury severity score ≥ 3 to spine.

before = data.shape[0]
data = data[data['AISSEVERITY6'] < 3]
after = data.shape[0]
excluded = before - after

print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  37599
# Number of patients after exclusion:  36004
# Number of patients excluded with this criteria:  1595

# %%
#Exclude AIS injury severity score ≥ 3 to upper extremity.

before = data.shape[0]
data = data[data['AISSEVERITY7'] < 3]
after = data.shape[0]
excluded = before - after

print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  36004
# Number of patients after exclusion:  35457
# Number of patients excluded with this criteria:  547

# %%
#Exclude AIS injury severity score ≥ 3 to lower extremity.

before = data.shape[0]
data = data[data['AISSEVERITY8'] < 3]
after = data.shape[0]
excluded = before - after

print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  35457
# Number of patients after exclusion:  32074
# Number of patients excluded with this criteria:  3383

# %%
#Exclude AIS injury severity score ≥ 3 to unspecified body regions.

before = data.shape[0]
data = data[data['AISSEVERITY9'] < 3]
after = data.shape[0]
excluded = before - after

print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  32074
# Number of patients after exclusion:  31991
# Number of patients excluded with this criteria:  83

# %%
#Exclude patients dead on arrival (SBP=0).

before = data.shape[0]
data = data[data['SBP'] != 0]
after = data.shape[0]
excluded = before - after

print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  31991
# Number of patients after exclusion:  30284
# Number of patients excluded with this criteria:  1707

# %%
#Exclude patients with advanced directive limiting care.

before = data.shape[0]
data = data[data['CC_ADLC'] != 'Yes']
after = data.shape[0]
excluded = before - after

print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  30284
# Number of patients after exclusion:  28984
# Number of patients excluded with this criteria:  1300

# %%
#Drop patients with invalid GCS.

before = data.shape[0]
data = data[data['PMGCSQ_VALID'] == 1]
after = data.shape[0]

excluded = before - after
print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  28984
# Number of patients after exclusion:  8940
# Number of patients excluded with this criteria:  20044

# %%
#Drop patients with unknown GCS.

before = data.shape[0]
data = data[data['TOTALGCS'].notna()]
after = data.shape[0]

excluded = before - after
print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  8940
# Number of patients after exclusion:  8940
# Number of patients excluded with this criteria:  0

# %%
#Drop patients with unknown GCS-Motor.

before = data.shape[0]
data = data[data['GCSMOTOR'].notna()]
after = data.shape[0]

excluded = before - after
print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  8940
# Number of patients after exclusion:  8883
# Number of patients excluded with this criteria:  57

# %%
#Assign GCS_VERBAL to 0 for intubated patients.

data.loc[data['GCSQ_INTUBATED'] == 1, 'GCSVERBAL'] = 0

data['GCSVERBAL'].value_counts(normalize=False, dropna=False)
# Out:
# 1.0    2551
# 0.0    2061
# 2.0    1785
# 4.0    1249
# 3.0    1129
# 5.0     108
# Name: GCSVERBAL, dtype: int64

# %%
#Drop patients with unknown GCS-Verbal.

before = data.shape[0]
data = data[data['GCSVERBAL'].notna()]
after = data.shape[0]

excluded = before - after
print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  8883
# Number of patients after exclusion:  8883
# Number of patients excluded with this criteria:  0

# %%
#Drop patients with unknown GCS-Eye.

before = data.shape[0]
data = data[data['GCSEYE'].notna()]
after = data.shape[0]

excluded = before - after
print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  8883
# Number of patients after exclusion:  8880
# Number of patients excluded with this criteria:  3

# %%
#Drop patients with unknown pupillary response.

before = data.shape[0]
data = data[data['TBIPUPILLARYRESPONSE'].notna()]
after = data.shape[0]

excluded = before - after
print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  8880
# Number of patients after exclusion:  8674
# Number of patients excluded with this criteria:  206

# %%
#Save data.

data.to_csv('/content/drive/MyDrive/TQP-MOST/2021_impact.csv')
