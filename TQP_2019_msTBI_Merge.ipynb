# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
#Read all data.

main_puf = pd.read_csv("/content/drive/MyDrive/NTDB-PUFs/NTDB_2019/PUF_TRAUMA.csv", index_col = 'inc_key', low_memory = False)
preexisting_conditions = pd.read_csv("/content/drive/MyDrive/NTDB-PUFs/NTDB_2019/PUF_PREEXISTINGCONDITIONS_PIVOT.csv", index_col = 'Inc_Key', low_memory = False)
hospital_events = pd.read_csv("/content/drive/MyDrive/NTDB-PUFs/NTDB_2019/PUF_HOSPITALEVENTS_PIVOT.csv", index_col = 'Inc_Key', low_memory = False)
ais = pd.read_csv("/content/drive/MyDrive/NTDB-PUFs/NTDB_2019/PUF_AISDIAGNOSIS_PIVOT.csv", index_col = 'inc_key', low_memory = False)
ecode = pd.read_csv("/content/drive/MyDrive/NTDB-PUFs/NTDB_2019/PUF_ECODE.csv", index_col = 'inc_key', low_memory = False)
interventions = pd.read_csv("/content/drive/MyDrive/NTDB-PUFs/NTDB_2019/PUF_INTERVENTIONS.csv", index_col = 'Inc_Key', low_memory = False)

# %%
data = pd.concat([main_puf, preexisting_conditions, hospital_events, ais, ecode, interventions], axis=1)
data.columns = map(str.upper, data.columns)
data.shape
# Out:
# (1097190, 372)

# %% [markdown]
# #Inclusion and Exclusion Criteria

# %%
#Identify the patient population.

data = data[(data['AISSEVERITY1'] == 2) | (data['AISSEVERITY1'] == 3) | (data['AISSEVERITY1'] == 4) | (data['AISSEVERITY1'] == 5)]

included = data.shape[0]

print('Number of patients included: ', included)
# Out:
# Number of patients included:  251474

# %%
#Exclude pediatric patients.

before = data.shape[0]
data = data[(data['AGEYEARS'] >= 18)]
after = data.shape[0]
excluded = before - after

print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  251474
# Number of patients after exclusion:  209761
# Number of patients excluded with this criteria:  41713

# %%
#Exclude AIS injury severity score ≥ 3 to neck.

before = data.shape[0]
data = data[data['AISSEVERITY3'] < 3]
after = data.shape[0]
excluded = before - after

print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  209761
# Number of patients after exclusion:  207549
# Number of patients excluded with this criteria:  2212

# %%
#Exclude AIS injury severity score ≥ 3 to thorax.

before = data.shape[0]
data = data[data['AISSEVERITY4'] < 3]
after = data.shape[0]
excluded = before - after

print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  207549
# Number of patients after exclusion:  179586
# Number of patients excluded with this criteria:  27963

# %%
#Exclude AIS injury severity score ≥ 3 to abdomen.

before = data.shape[0]
data = data[data['AISSEVERITY5'] < 3]
after = data.shape[0]
excluded = before - after

print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  179586
# Number of patients after exclusion:  177255
# Number of patients excluded with this criteria:  2331

# %%
#Exclude AIS injury severity score ≥ 3 to spine.

before = data.shape[0]
data = data[data['AISSEVERITY6'] < 3]
after = data.shape[0]
excluded = before - after

print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  177255
# Number of patients after exclusion:  172438
# Number of patients excluded with this criteria:  4817

# %%
#Exclude AIS injury severity score ≥ 3 to upper extremity.

before = data.shape[0]
data = data[data['AISSEVERITY7'] < 3]
after = data.shape[0]
excluded = before - after

print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  172438
# Number of patients after exclusion:  171661
# Number of patients excluded with this criteria:  777

# %%
#Exclude AIS injury severity score ≥ 3 to lower extremity.

before = data.shape[0]
data = data[data['AISSEVERITY8'] < 3]
after = data.shape[0]
excluded = before - after

print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  171661
# Number of patients after exclusion:  165244
# Number of patients excluded with this criteria:  6417

# %%
#Exclude AIS injury severity score ≥ 3 to unspecified body regions.

before = data.shape[0]
data = data[data['AISSEVERITY9'] < 3]
after = data.shape[0]
excluded = before - after

print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  165244
# Number of patients after exclusion:  165199
# Number of patients excluded with this criteria:  45

# %%
#Exclude patients dead on arrival (SBP=0).

before = data.shape[0]
data = data[data['SBP'] != 0]
after = data.shape[0]
excluded = before - after

print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  165199
# Number of patients after exclusion:  164283
# Number of patients excluded with this criteria:  916

# %%
#Exclude patients with advanced directive limiting care.

before = data.shape[0]
data = data[data['CC_ADLC'] != 'Yes']
after = data.shape[0]
excluded = before - after

print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  164283
# Number of patients after exclusion:  157141
# Number of patients excluded with this criteria:  7142

# %%
#Drop patients with invalid GCS.

before = data.shape[0]
data = data[data['PMGCSQ_VALID'] == 1]
after = data.shape[0]

excluded = before - after
print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  157141
# Number of patients after exclusion:  125205
# Number of patients excluded with this criteria:  31936

# %%
#Drop patients with unknown GCS.

before = data.shape[0]
data = data[data['TOTALGCS'].notna()]
after = data.shape[0]

excluded = before - after
print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  125205
# Number of patients after exclusion:  120707
# Number of patients excluded with this criteria:  4498

# %%
#Drop patients with unknown GCS-Motor.

before = data.shape[0]
data = data[data['GCSMOTOR'].notna()]
after = data.shape[0]

excluded = before - after
print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  120707
# Number of patients after exclusion:  120501
# Number of patients excluded with this criteria:  206

# %%
#Drop patients with unknown GCS-Verbal.

before = data.shape[0]
data = data[data['GCSVERBAL'].notna()]
after = data.shape[0]

excluded = before - after
print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  120501
# Number of patients after exclusion:  120490
# Number of patients excluded with this criteria:  11

# %%
#Drop patients with unknown GCS-Eye.

before = data.shape[0]
data = data[data['GCSEYE'].notna()]
after = data.shape[0]

excluded = before - after
print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  120490
# Number of patients after exclusion:  120490
# Number of patients excluded with this criteria:  0

# %%
#Drop patients with unknown pupillary response.

before = data.shape[0]
data = data[data['TBIPUPILLARYRESPONSE'].notna()]
after = data.shape[0]

excluded = before - after
print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  120490
# Number of patients after exclusion:  115844
# Number of patients excluded with this criteria:  4646

# %%
#Save data.

data.to_csv('/content/drive/MyDrive/GCS-Pupil/stbi_2019.csv')
