# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np

# %%
#Read all data.

main_puf = pd.read_csv("/content/drive/MyDrive/NTDB-PUFs/NTDB_2019/PUF_TRAUMA.csv", index_col = 'inc_key', low_memory = False)
preexisting_conditions = pd.read_csv("/content/drive/MyDrive/NTDB-PUFs/NTDB_2019/PUF_PREEXISTINGCONDITIONS_PIVOT.csv", index_col = 'Inc_Key', low_memory = False)
hospital_events = pd.read_csv("/content/drive/MyDrive/NTDB-PUFs/NTDB_2019/PUF_HOSPITALEVENTS_PIVOT.csv", index_col = 'Inc_Key', low_memory = False)
ais = pd.read_csv("/content/drive/MyDrive/NTDB-PUFs/NTDB_2019/PUF_AISDIAGNOSIS_PIVOT.csv", index_col = 'inc_key', low_memory = False)
ecode = pd.read_csv("/content/drive/MyDrive/NTDB-PUFs/NTDB_2019/PUF_ECODE.csv", index_col = 'inc_key', low_memory = False)
interventions = pd.read_csv("/content/drive/MyDrive/NTDB-PUFs/NTDB_2019/PUF_INTERVENTIONS.csv", index_col = 'Inc_Key', low_memory = False)

# %%
data = pd.concat([main_puf, preexisting_conditions, hospital_events, ais, ecode, interventions], axis=1)
data.columns = map(str.upper, data.columns)
data.shape
# Out:
# (1097190, 372)

# %% [markdown]
# #Inclusion and Exclusion Criteria

# %%
#Identify the patient population.

data = data[(data['AISSEVERITY1'] == 2) | (data['AISSEVERITY1'] == 3) | (data['AISSEVERITY1'] == 4) | (data['AISSEVERITY1'] == 5)]
data = data[(data['VERIFICATIONLEVEL'] == 1) | (data['VERIFICATIONLEVEL'] == 2)]

included = data.shape[0]

print('Number of patients included: ', included)
# Out:
# Number of patients included:  173635

# %%
#Exclude pediatric patients.

before = data.shape[0]
data = data[(data['AGEYEARS'] >= 18)]
after = data.shape[0]
excluded = before - after

print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  173635
# Number of patients after exclusion:  151244
# Number of patients excluded with this criteria:  22391

# %%
#Exclude AIS injury severity score ≥ 3 to neck.

before = data.shape[0]
data = data[data['AISSEVERITY3'] < 3]
after = data.shape[0]
excluded = before - after

print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  151244
# Number of patients after exclusion:  149534
# Number of patients excluded with this criteria:  1710

# %%
#Exclude AIS injury severity score ≥ 3 to thorax.

before = data.shape[0]
data = data[data['AISSEVERITY4'] < 3]
after = data.shape[0]
excluded = before - after

print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  149534
# Number of patients after exclusion:  128451
# Number of patients excluded with this criteria:  21083

# %%
#Exclude AIS injury severity score ≥ 3 to abdomen.

before = data.shape[0]
data = data[data['AISSEVERITY5'] < 3]
after = data.shape[0]
excluded = before - after

print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  128451
# Number of patients after exclusion:  126674
# Number of patients excluded with this criteria:  1777

# %%
#Exclude AIS injury severity score ≥ 3 to spine.

before = data.shape[0]
data = data[data['AISSEVERITY6'] < 3]
after = data.shape[0]
excluded = before - after

print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  126674
# Number of patients after exclusion:  123099
# Number of patients excluded with this criteria:  3575

# %%
#Exclude AIS injury severity score ≥ 3 to upper extremity.

before = data.shape[0]
data = data[data['AISSEVERITY7'] < 3]
after = data.shape[0]
excluded = before - after

print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  123099
# Number of patients after exclusion:  122543
# Number of patients excluded with this criteria:  556

# %%
#Exclude AIS injury severity score ≥ 3 to lower extremity.

before = data.shape[0]
data = data[data['AISSEVERITY8'] < 3]
after = data.shape[0]
excluded = before - after

print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  122543
# Number of patients after exclusion:  117791
# Number of patients excluded with this criteria:  4752

# %%
#Exclude AIS injury severity score ≥ 3 to unspecified body regions.

before = data.shape[0]
data = data[data['AISSEVERITY9'] < 3]
after = data.shape[0]
excluded = before - after

print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  117791
# Number of patients after exclusion:  117753
# Number of patients excluded with this criteria:  38

# %%
#Exclude patients dead on arrival (SBP=0).

before = data.shape[0]
data = data[data['SBP'] != 0]
after = data.shape[0]
excluded = before - after

print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  117753
# Number of patients after exclusion:  117130
# Number of patients excluded with this criteria:  623

# %%
#Exclude patients with advanced directive limiting care.

before = data.shape[0]
data = data[data['CC_ADLC'] != 'Yes']
after = data.shape[0]
excluded = before - after

print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  117130
# Number of patients after exclusion:  112093
# Number of patients excluded with this criteria:  5037

# %%
#Drop patients with eye obstruction.

before = data.shape[0]
data = data[data['GCSQ_EYEOBSTRUCTION'] == 0]
after = data.shape[0]

excluded = before - after
print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  112093
# Number of patients after exclusion:  111474
# Number of patients excluded with this criteria:  619

# %%
#Drop patients chemically sedated or paralyzed.

before = data.shape[0]
data = data[data['GCSQ_SEDATEDPARALYZED'] == 0]
after = data.shape[0]

excluded = before - after
print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  111474
# Number of patients after exclusion:  106090
# Number of patients excluded with this criteria:  5384

# %%
#Drop patients with unknown GCS.

before = data.shape[0]
data = data[data['GCSQ_UK'] == 0]
after = data.shape[0]

excluded = before - after
print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  106090
# Number of patients after exclusion:  101672
# Number of patients excluded with this criteria:  4418

# %%
#Drop patients with unknown GCS.

before = data.shape[0]
data = data[data['TOTALGCS'].notna()]
after = data.shape[0]

excluded = before - after
print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  101672
# Number of patients after exclusion:  99293
# Number of patients excluded with this criteria:  2379

# %%
#Drop patients with unknown GCS-Motor.

before = data.shape[0]
data = data[data['GCSMOTOR'].notna()]
after = data.shape[0]

excluded = before - after
print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  99293
# Number of patients after exclusion:  99119
# Number of patients excluded with this criteria:  174

# %%
#Drop patients with unknown GCS-Verbal.

before = data.shape[0]
data = data[data['GCSVERBAL'].notna()]
after = data.shape[0]

excluded = before - after
print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  99119
# Number of patients after exclusion:  99114
# Number of patients excluded with this criteria:  5

# %%
#Drop patients with unknown GCS-Eye.

before = data.shape[0]
data = data[data['GCSEYE'].notna()]
after = data.shape[0]

excluded = before - after
print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  99114
# Number of patients after exclusion:  99114
# Number of patients excluded with this criteria:  0

# %%
#Drop patients with unknown pupillary response.

before = data.shape[0]
data = data[data['TBIPUPILLARYRESPONSE'].notna()]
after = data.shape[0]

excluded = before - after
print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  99114
# Number of patients after exclusion:  94860
# Number of patients excluded with this criteria:  4254

# %%
#Assign GCS_VERBAL to 0 for intubated patients.

data.loc[data['GCSQ_INTUBATED'] == 1, 'GCSVERBAL'] = 0

data['GCSVERBAL'].value_counts(normalize=False, dropna=False)
# Out:
# 5.0    69508
# 4.0    19162
# 1.0     4474
# NaN     2482
# 0.0     2262
# 2.0     2207
# 3.0     1577
# Name: GCSVERBAL, dtype: int64

# %%
#Save data.

data.to_csv('/content/drive/MyDrive/TQP-MOST/2019.csv')
