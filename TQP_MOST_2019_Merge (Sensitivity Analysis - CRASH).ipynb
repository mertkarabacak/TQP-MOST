# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
#Read all data.

main_puf = pd.read_csv("/content/drive/MyDrive/NTDB-PUFs/NTDB_2019/PUF_TRAUMA.csv", index_col = 'inc_key', low_memory = False)
preexisting_conditions = pd.read_csv("/content/drive/MyDrive/NTDB-PUFs/NTDB_2019/PUF_PREEXISTINGCONDITIONS_PIVOT.csv", index_col = 'Inc_Key', low_memory = False)
hospital_events = pd.read_csv("/content/drive/MyDrive/NTDB-PUFs/NTDB_2019/PUF_HOSPITALEVENTS_PIVOT.csv", index_col = 'Inc_Key', low_memory = False)
ais = pd.read_csv("/content/drive/MyDrive/NTDB-PUFs/NTDB_2019/PUF_AISDIAGNOSIS_PIVOT.csv", index_col = 'inc_key', low_memory = False)
ecode = pd.read_csv("/content/drive/MyDrive/NTDB-PUFs/NTDB_2019/PUF_ECODE.csv", index_col = 'inc_key', low_memory = False)
interventions = pd.read_csv("/content/drive/MyDrive/NTDB-PUFs/NTDB_2019/PUF_INTERVENTIONS.csv", index_col = 'Inc_Key', low_memory = False)

# %%
data = pd.concat([main_puf, preexisting_conditions, hospital_events, ais, ecode, interventions], axis=1)
data.columns = map(str.upper, data.columns)
data.shape
# Out:
# (1097190, 372)

# %% [markdown]
# #Inclusion and Exclusion Criteria

# %%
#Identify the patient population.

data = data[(data['TOTALGCS'] <= 14)]
data = data[(data['VERIFICATIONLEVEL'] == 1) | (data['VERIFICATIONLEVEL'] == 2)]

included = data.shape[0]

print('Number of patients included: ', included)
# Out:
# Number of patients included:  126206

# %%
#Exclude pediatric patients.

before = data.shape[0]
data = data[(data['AGEYEARS'] >= 16)]
after = data.shape[0]
excluded = before - after

print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  126206
# Number of patients after exclusion:  112417
# Number of patients excluded with this criteria:  13789

# %%
#Exclude AIS injury severity score ≥ 3 to neck.

before = data.shape[0]
data = data[data['AISSEVERITY3'] < 3]
after = data.shape[0]
excluded = before - after

print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  112417
# Number of patients after exclusion:  110099
# Number of patients excluded with this criteria:  2318

# %%
#Exclude AIS injury severity score ≥ 3 to thorax.

before = data.shape[0]
data = data[data['AISSEVERITY4'] < 3]
after = data.shape[0]
excluded = before - after

print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  110099
# Number of patients after exclusion:  85854
# Number of patients excluded with this criteria:  24245

# %%
#Exclude AIS injury severity score ≥ 3 to abdomen.

before = data.shape[0]
data = data[data['AISSEVERITY5'] < 3]
after = data.shape[0]
excluded = before - after

print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  85854
# Number of patients after exclusion:  82765
# Number of patients excluded with this criteria:  3089

# %%
#Exclude AIS injury severity score ≥ 3 to spine.

before = data.shape[0]
data = data[data['AISSEVERITY6'] < 3]
after = data.shape[0]
excluded = before - after

print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  82765
# Number of patients after exclusion:  79497
# Number of patients excluded with this criteria:  3268

# %%
#Exclude AIS injury severity score ≥ 3 to upper extremity.

before = data.shape[0]
data = data[data['AISSEVERITY7'] < 3]
after = data.shape[0]
excluded = before - after

print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  79497
# Number of patients after exclusion:  78686
# Number of patients excluded with this criteria:  811

# %%
#Exclude AIS injury severity score ≥ 3 to lower extremity.

before = data.shape[0]
data = data[data['AISSEVERITY8'] < 3]
after = data.shape[0]
excluded = before - after

print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  78686
# Number of patients after exclusion:  69465
# Number of patients excluded with this criteria:  9221

# %%
#Exclude AIS injury severity score ≥ 3 to unspecified body regions.

before = data.shape[0]
data = data[data['AISSEVERITY9'] < 3]
after = data.shape[0]
excluded = before - after

print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  69465
# Number of patients after exclusion:  69162
# Number of patients excluded with this criteria:  303

# %%
#Exclude patients dead on arrival (SBP=0).

before = data.shape[0]
data = data[data['SBP'] != 0]
after = data.shape[0]
excluded = before - after

print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  69162
# Number of patients after exclusion:  67849
# Number of patients excluded with this criteria:  1313

# %%
#Exclude patients with advanced directive limiting care.

before = data.shape[0]
data = data[data['CC_ADLC'] != 'Yes']
after = data.shape[0]
excluded = before - after

print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  67849
# Number of patients after exclusion:  64336
# Number of patients excluded with this criteria:  3513

# %%
#Drop patients with eye obstruction.

before = data.shape[0]
data = data[data['GCSQ_EYEOBSTRUCTION'] == 0]
after = data.shape[0]

excluded = before - after
print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  64336
# Number of patients after exclusion:  63710
# Number of patients excluded with this criteria:  626

# %%
#Drop patients chemically sedated or paralyzed.

before = data.shape[0]
data = data[data['GCSQ_SEDATEDPARALYZED'] == 0]
after = data.shape[0]

excluded = before - after
print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  63710
# Number of patients after exclusion:  56341
# Number of patients excluded with this criteria:  7369

# %%
#Drop patients chemically sedated or paralyzed.

before = data.shape[0]
data = data[data['GCSQ_INTUBATED'] == 0]
after = data.shape[0]

excluded = before - after
print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  56341
# Number of patients after exclusion:  53279
# Number of patients excluded with this criteria:  3062

# %%
#Drop patients with unknown GCS.

before = data.shape[0]
data = data[data['GCSQ_UK'] == 0]
after = data.shape[0]

excluded = before - after
print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  53279
# Number of patients after exclusion:  51721
# Number of patients excluded with this criteria:  1558

# %%
#Drop patients with unknown GCS.

before = data.shape[0]
data = data[data['TOTALGCS'].notna()]
after = data.shape[0]

excluded = before - after
print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  51721
# Number of patients after exclusion:  51721
# Number of patients excluded with this criteria:  0

# %%
#Drop patients with unknown GCS-Motor.

before = data.shape[0]
data = data[data['GCSMOTOR'].notna()]
after = data.shape[0]

excluded = before - after
print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  51721
# Number of patients after exclusion:  51440
# Number of patients excluded with this criteria:  281

# %%
#Assign GCS_VERBAL to 0 for intubated patients.

data.loc[data['GCSQ_INTUBATED'] == 1, 'GCSVERBAL'] = 0

data['GCSVERBAL'].value_counts(normalize=False, dropna=False)
# Out:
# 4.0    34930
# 1.0     6430
# 5.0     3971
# 2.0     3475
# 3.0     2631
# NaN        3
# Name: GCSVERBAL, dtype: int64

# %%
#Drop patients with unknown GCS-Verbal.

before = data.shape[0]
data = data[data['GCSVERBAL'].notna()]
after = data.shape[0]

excluded = before - after
print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  51440
# Number of patients after exclusion:  51437
# Number of patients excluded with this criteria:  3

# %%
#Drop patients with unknown GCS-Eye.

before = data.shape[0]
data = data[data['GCSEYE'].notna()]
after = data.shape[0]

excluded = before - after
print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  51437
# Number of patients after exclusion:  51437
# Number of patients excluded with this criteria:  0

# %%
#Drop patients with unknown pupillary response.

before = data.shape[0]
data = data[data['TBIPUPILLARYRESPONSE'].notna()]
after = data.shape[0]

excluded = before - after
print('Number of patients before exclusion: ', before)
print('Number of patients after exclusion: ', after)
print('Number of patients excluded with this criteria: ', excluded)
# Out:
# Number of patients before exclusion:  51437
# Number of patients after exclusion:  32579
# Number of patients excluded with this criteria:  18858

# %%
#Save data.

data.to_csv('/content/drive/MyDrive/TQP-MOST/2019_crash.csv')
